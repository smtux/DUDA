# %%
import pandas as pd
import matplotlib.pyplot as plt
#import missingno as msno

# %%
# Chargement des données
ins_prof_dut = pd.read_csv("../csv/fr-esr-insertion_professionnelle-dut_donnees_nationales.csv", sep=";")
ins_prof_lp = pd.read_csv("../csv//fr-esr-insertion_professionnelle-lp_donnees_nationales.csv", sep=";")
ins_prof_master = pd.read_csv("../csv/fr-esr-insertion_professionnelle-master_donnees_nationales.csv", sep=";")

# %%
# Agrégation de toutes les formations (DUT, LP, MASTER)
ins_prof = pd.concat([ins_prof_dut, ins_prof_lp, ins_prof_master])

# %%
ins_prof.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5920 entries, 0 to 2924
# Data columns (total 86 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Année                                                                  5920 non-null   object
#  1   Diplôme                                                                5920 non-null   object
#  2   situation                                                              5920 non-null   object
#  3   Genre                                                                  5920 non-null   object
#  4   Disciplines                                                            5920 non-null   object
#  5   Code du domaine                                                        5920 non-null   object
#  6   Domaine                                                                5920 non-null   object
#  7   Code de la discipline                                                  5920 non-null   object
#  8   Discipline                                                             5920 non-null   object
#  9   Sigle                                                                  932 non-null    object
#  10  Spécialité                                                             1128 non-null   object
#  11  Nombre de réponses                                                     5484 non-null   float64
#  12  Taux d’insertion                                                       5890 non-null   object
#  13  Part des emplois de niveau cadre ou profession intermédiaire           5890 non-null   object
#  14  Part des emplois de niveau cadre                                       5761 non-null   object
#  15  % emplois extérieurs à la région de l’université                       5890 non-null   object
#  16  Part des emplois stables                                               5890 non-null   object
#  17  Part des emplois à temps plein                                         5890 non-null   object
#  18  Salaire net mensuel médian des emplois à temps plein                   5890 non-null   object
#  19  Salaire brut annuel estimé                                             5890 non-null   object
#  20  Premier quartile des salaires nets mensuels des emplois à temps plein  5890 non-null   object
#  21  Dernier quartile des salaires nets mensuels des emplois à temps plein  5890 non-null   object
#  22  Part des diplômés boursiers dans la discipline                         5676 non-null   object
#  23  Part des femmes                                                        2154 non-null   object
#  24  Taux de chômage national                                               5920 non-null   float64
#  25  Salaire net mensuel médian national                                    5920 non-null   int64
#  26  Code du secteur disciplinaire SISE                                     4013 non-null   object
#  27  Salaire net mensuel national 1er quartile                              5861 non-null   float64
#  28  Salaire net mensuel national 3ème quartile                             5861 non-null   float64
#  29  cle_DISC                                                               5920 non-null   object
#  30  Prof. libérale, indépendant,' chef d’entreprise                        860 non-null    object
#  31  Fonctionnaire                                                          1502 non-null   object
#  32  CDI                                                                    1502 non-null   object
#  33  CDI de chantier ou CDI de mission                                      1079 non-null   object
#  34  Contrat spécifique au doctorat                                         183 non-null    object
#  35  CDD                                                                    1502 non-null   object
#  36  Vacataire                                                              1502 non-null   object
#  37  Intérimaire                                                            1502 non-null   object
#  38  Intermittent du spectacle                                              1500 non-null   object
#  39  Contrat de professionnalisa tion                                       860 non-null    object
#  40  Emplois aidés (Contrat Initiative Emploi…)                             1484 non-null   object
#  41  Volontariat international                                              1465 non-null   object
#  42  Vous-même                                                              745 non-null    object
#  43  La fonction publique (d''etat',' territoriale ou hospitalière)         433 non-null    object
#  44  Une entreprise privée                                                  745 non-null    object
#  45  Une entreprise publique                                                745 non-null    object
#  46  Une association                                                        745 non-null    object
#  47  Une personne exerçant une profession libérale ou un indépendant        745 non-null    object
#  48  Organisation internationale ou une institution de l''Union européenne  297 non-null    object
#  49  Société d''économie mixte                                              310 non-null    object
#  50  Un particulier                                                         745 non-null    object
#  51  Agriculture', sylviculture et pêche                                    432 non-null    object
#  52  Industries (manufacturières,  extractives et autres)                   744 non-null    object
#  53  Construction                                                           744 non-null    object
#  54  Activités immobilières                                                 546 non-null    object
#  55  Commerce, transports, héberg-ement et restauration                     744 non-null    object
#  56  Information et communication                                           744 non-null    object
#  57  Activités financières et d’assurance                                   744 non-null    object
#  58  Activités spécialisées, scientifiques et techniques                    744 non-null    object
#  59  Activités de services administratifs et de soutien                     744 non-null    object
#  60  Enseignement                                                           744 non-null    object
#  61  Administra tion publique (hors ens.)                                   174 non-null    object
#  62  Santé humaine et action sociale                                        744 non-null    object
#  63  Arts, spectacles et activités récréatives                              744 non-null    object
#  64  Autres activités de service                                            744 non-null    object
#  65  Agriculteur                                                            1036 non-null   object
#  66  Artisan, commerçant,' chef d''entreprise                               602 non-null    object
#  67  Profession libérale                                                    1087 non-null   object
#  68  Personnel de catégorie A de la fonction publique                       1484 non-null   object
#  69  Ingénieur', cadre, prof. libérales, prof. intellectuelles sup          860 non-null    object
#  70  Personnel de catégorie B de la fonction publique                       1484 non-null   object
#  71  Emploi de niveau intermédiaire : technicien, agent de maîtrise…        1484 non-null   object
#  72  Personnel de catégorie C de la fonction publique                       1484 non-null   object
#  73  Manœuvre, ouvrier                                                      1484 non-null   object
#  74  Employé de bureau, de commerce, personnel de service                   3619 non-null   object
#  75  Code du secteur disciplinaire                                          4792 non-null   object
#  76  Secteur disciplinaire                                                  4792 non-null   object
#  77  Administration publique (hors ens.)                                    570 non-null    object
#  78  Prof. libérale, indépendant, chef d’entreprise                         642 non-null    object
#  79  Contrat de professionnalisation                                        640 non-null    object
#  80  La fonction publique (d'etat, territoriale ou hospitalière)            312 non-null    object
#  81  Organisation internationale ou une institution de l'Union européenne   236 non-null    object
#  82  Société d'économie mixte                                               236 non-null    object
#  83  Agriculture, sylviculture et pêche                                     311 non-null    object
#  84  Artisan, commerçant, chef d'entreprise                                 472 non-null    object
#  85  Ingénieur, cadre, prof. libérales, prof. intellectuelles sup           624 non-null    object
# dtypes: float64(4), int64(1), object(81)
# memory usage: 3.9+ MB

# %%
# changement de type de la variable "Année" en datetime
ins_prof["Année"] = pd.to_datetime(ins_prof["Année"])
ins_prof["Année"] = ins_prof["Année"].dt.year

# %%
ins_prof["Année"]
# Out:
# 0       2013
# 1       2017
# 2       2017
# 3       2017
# 4       2017
#         ...
# 2920    1970
# 2921    1970
# 2922    1970
# 2923    1970
# 2924    1970
# Name: Année, Length: 5920, dtype: int64

# %%
ins_prof.set_index("Année", inplace=True)

# %%
ins_prof
# Out:
#           Diplôme                 situation             Genre  \
# Année
# 2013          DUT  30 mois après le diplôme            hommes
# 2017          DUT  18 mois après le diplôme  femmes et hommes
# 2017          DUT  18 mois après le diplôme            hommes
# 2017          DUT  18 mois après le diplôme  femmes et hommes
# 2017          DUT  18 mois après le diplôme            femmes
# ...           ...                       ...               ...
# 1970   MASTER ENS  18 mois après le diplôme            femmes
# 1970   MASTER ENS  30 mois après le diplôme  femmes et hommes
# 1970   MASTER ENS  30 mois après le diplôme            femmes
# 1970   MASTER ENS  18 mois après le diplôme            hommes
# 1970   MASTER ENS  30 mois après le diplôme            femmes
#
#                                              Disciplines Code du domaine  \
# Année
# 2013   Droit, économie et gestion>Droit>Carrières jur...             DEG
# 2017   Sciences, technologies et santé>Informatique>I...             STS
# 2017   Sciences, technologies et santé>Informatique>I...             STS
# 2017   Sciences humaines et sociales>Information comm...             SHS
# 2017   Sciences humaines et sociales>Information comm...             SHS
# ...                                                  ...             ...
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
#
#                                Domaine Code de la discipline  \
# Année
# 2013        Droit, économie et gestion                disc02
# 2017   Sciences, technologies et santé                disc16
# 2017   Sciences, technologies et santé                disc16
# 2017     Sciences humaines et sociales                disc10
# 2017     Sciences humaines et sociales                disc10
# ...                                ...                   ...
# 1970              Masters enseignement                disc18
# 1970              Masters enseignement                disc18
# 1970              Masters enseignement                disc18
# 1970              Masters enseignement                disc18
# 1970              Masters enseignement                disc18
#
#                       Discipline Sigle                 Spécialité  ...  \
# Année                                                              ...
# 2013                       Droit   NaN       Carrières juridiques  ...
# 2017                Informatique   NaN               Informatique  ...
# 2017                Informatique   NaN               Informatique  ...
# 2017   Information communication   NaN  Information-Communication  ...
# 2017   Information communication   NaN  Information-Communication  ...
# ...                          ...   ...                        ...  ...
# 1970        Masters enseignement   NaN                        NaN  ...
# 1970        Masters enseignement   NaN                        NaN  ...
# 1970        Masters enseignement   NaN                        NaN  ...
# 1970        Masters enseignement   NaN                        NaN  ...
# 1970        Masters enseignement   NaN                        NaN  ...
#
#        Secteur disciplinaire Administration publique (hors ens.)  \
# Année
# 2013                     NaN                                 NaN
# 2017                     NaN                                 NaN
# 2017                     NaN                                 NaN
# 2017                     NaN                                 NaN
# 2017                     NaN                                 NaN
# ...                      ...                                 ...
# 1970    Masters enseignement                                 NaN
# 1970    Masters enseignement                                   2
# 1970    Masters enseignement                                 NaN
# 1970    Masters enseignement                                 NaN
# 1970    Masters enseignement                                 NaN
#
#       Prof. libérale, indépendant, chef d’entreprise  \
# Année
# 2013                                             NaN
# 2017                                             NaN
# 2017                                             NaN
# 2017                                             NaN
# 2017                                             NaN
# ...                                              ...
# 1970                                             NaN
# 1970                                               1
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
#
#       Contrat de professionnalisation  \
# Année
# 2013                              NaN
# 2017                              NaN
# 2017                              NaN
# 2017                              NaN
# 2017                              NaN
# ...                               ...
# 1970                              NaN
# 1970                                0
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
#
#       La fonction publique (d'etat, territoriale ou hospitalière)  \
# Année
# 2013                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# ...                                                  ...
# 1970                                                 NaN
# 1970                                                  89
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
#
#       Organisation internationale ou une institution de l'Union européenne  \
# Année
# 2013                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# ...                                                  ...
# 1970                                                 NaN
# 1970                                                   0
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
#
#       Société d'économie mixte Agriculture, sylviculture et pêche  \
# Année
# 2013                       NaN                                NaN
# 2017                       NaN                                NaN
# 2017                       NaN                                NaN
# 2017                       NaN                                NaN
# 2017                       NaN                                NaN
# ...                        ...                                ...
# 1970                       NaN                                NaN
# 1970                         0                                  0
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
#
#       Artisan, commerçant, chef d'entreprise  \
# Année
# 2013                                     NaN
# 2017                                     NaN
# 2017                                     NaN
# 2017                                     NaN
# 2017                                     NaN
# ...                                      ...
# 1970                                     NaN
# 1970                                       0
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
#
#       Ingénieur, cadre, prof. libérales, prof. intellectuelles sup
# Année
# 2013                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# 2017                                                 NaN
# ...                                                  ...
# 1970                                                 NaN
# 1970                                                   4
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
#
# [5920 rows x 85 columns]

# %%
ins_prof.sort_index(level=0, inplace=True)

# %%
ins_prof
# Out:
#            Diplôme                 situation             Genre  \
# Année
# 1970    MASTER ENS  30 mois après le diplôme            femmes
# 1970    MASTER LMD  18 mois après le diplôme  femmes et hommes
# 1970    MASTER LMD  18 mois après le diplôme  femmes et hommes
# 1970    MASTER LMD  30 mois après le diplôme            hommes
# 1970    MASTER LMD  30 mois après le diplôme            femmes
# ...            ...                       ...               ...
# 2019           DUT  30 mois après le diplôme            femmes
# 2019           DUT  18 mois après le diplôme            femmes
# 2019           DUT  18 mois après le diplôme            hommes
# 2019   LICENCE PRO  30 mois après le diplôme            hommes
# 2019           DUT  18 mois après le diplôme            femmes
#
#                                              Disciplines Code du domaine  \
# Année
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# ...                                                  ...             ...
# 2019   Droit, économie et gestion>Autres formations j...             DEG
# 2019   Droit, économie et gestion>Autres formations j...             DEG
# 2019   Sciences,' technologies et santé>Sciences de l...             STS
# 2019   Sciences humaines et sociales>Information comm...             SHS
# 2019   Sciences humaines et sociales>Autres sciences ...             SHS
#
#                                  Domaine Code de la discipline  \
# Année
# 1970                Masters enseignement                disc18
# 1970     Sciences, technologies et santé                disc14
# 1970     Sciences, technologies et santé                disc14
# 1970     Sciences, technologies et santé                disc14
# 1970     Sciences, technologies et santé                disc14
# ...                                  ...                   ...
# 2019          Droit, économie et gestion                disc05
# 2019          Droit, économie et gestion                disc05
# 2019   Sciences',' technologies et santé                disc15
# 2019       Sciences humaines et sociales                disc10
# 2019       Sciences humaines et sociales                disc11
#
#                                               Discipline   Sigle  \
# Année
# 1970                                Masters enseignement     NaN
# 1970                              Sciences fondamentales     NaN
# 1970                              Sciences fondamentales     NaN
# 1970                              Sciences fondamentales     NaN
# 1970                              Sciences fondamentales     NaN
# ...                                                  ...     ...
# 2019   Autres formations juridiques, économiques et d...    GACO
# 2019   Autres formations juridiques, économiques et d...    GACO
# 2019                            Sciences de l''ingénieur  disc15
# 2019                           Information communication     NaN
# 2019                Autres sciences humaines et sociales      CS
#
#                                               Spécialité  ...  \
# Année                                                     ...
# 1970                                                 NaN  ...
# 1970                                                 NaN  ...
# 1970                                                 NaN  ...
# 1970                                                 NaN  ...
# 1970                                                 NaN  ...
# ...                                                  ...  ...
# 2019   gestion administrative et commerciale des orga...  ...
# 2019   gestion administrative et commerciale des orga...  ...
# 2019                            Sciences de l''ingénieur  ...
# 2019                                                 NaN  ...
# 2019                                  Carrières sociales  ...
#
#                                 Secteur disciplinaire  \
# Année
# 1970                             Masters enseignement
# 1970                               Physique et chimie
# 1970                               Physique et chimie
# 1970                               Physique et chimie
# 1970                                         Physique
# ...                                               ...
# 2019                                              NaN
# 2019                                              NaN
# 2019                                              NaN
# 2019   Sciences de l''information et la communication
# 2019                                              NaN
#
#       Administration publique (hors ens.)  \
# Année
# 1970                                  NaN
# 1970                                  NaN
# 1970                                  NaN
# 1970                                  NaN
# 1970                                  NaN
# ...                                   ...
# 2019                                  NaN
# 2019                                  NaN
# 2019                                  NaN
# 2019                                   14
# 2019                                  NaN
#
#       Prof. libérale, indépendant, chef d’entreprise  \
# Année
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# ...                                              ...
# 2019                                             NaN
# 2019                                             NaN
# 2019                                             NaN
# 2019                                             NaN
# 2019                                             NaN
#
#       Contrat de professionnalisation  \
# Année
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# ...                               ...
# 2019                              NaN
# 2019                              NaN
# 2019                              NaN
# 2019                              NaN
# 2019                              NaN
#
#       La fonction publique (d'etat, territoriale ou hospitalière)  \
# Année
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# ...                                                  ...
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
#
#       Organisation internationale ou une institution de l'Union européenne  \
# Année
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# ...                                                  ...
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
#
#       Société d'économie mixte Agriculture, sylviculture et pêche  \
# Année
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# ...                        ...                                ...
# 2019                       NaN                                NaN
# 2019                       NaN                                NaN
# 2019                       NaN                                NaN
# 2019                       NaN                                NaN
# 2019                       NaN                                NaN
#
#       Artisan, commerçant, chef d'entreprise  \
# Année
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# ...                                      ...
# 2019                                     NaN
# 2019                                     NaN
# 2019                                     NaN
# 2019                                     NaN
# 2019                                     NaN
#
#       Ingénieur, cadre, prof. libérales, prof. intellectuelles sup
# Année
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# ...                                                  ...
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
# 2019                                                 NaN
#
# [5920 rows x 85 columns]

# %%
ins_prof["Discipline"].unique()
# Out:
# array(['Masters enseignement', 'Sciences fondamentales',
#        'Sciences de la vie et de la terre',
#        'Ensemble sciences, technologies et santé',
#        'Autres sciences humaines et sociales',
#        'Autres sciences, technologies et santé', 'Informatique',
#        "Sciences de l'ingénieur", 'Histoire-géographie',
#        'Ensemble sciences humaines et sociales', 'Lettres, langues, arts',
#        'Information communication', 'Psychologie', 'Droit',
#        'Ensemble formations juridiques, économiques et de gestion',
#        'Ensemble Masters LMD (hors Masters enseignement et hors Dauphine et Antilles-Guyane)',
#        'Gestion', 'Économie',
#        'Ensemble Masters LMD (hors Masters enseignement)',
#        'Autres formations juridiques, économiques et de gestion',
#        'Masters enseignement : second degré, CPE...',
#        'Masters enseignement : premier degré',
#        'Ensemble Licence professionnelle', "Sciences de l''ingénieur",
#        "Ensemble des départements d''IUT",
#        "Autres sciences,' technologies et santé"], dtype=object)

# %%
ins_prof[ins_prof["Diplôme"].str.contains("MASTER")]
# Out:
#           Diplôme                 situation             Genre  \
# Année
# 1970   MASTER ENS  30 mois après le diplôme            femmes
# 1970   MASTER LMD  18 mois après le diplôme  femmes et hommes
# 1970   MASTER LMD  18 mois après le diplôme  femmes et hommes
# 1970   MASTER LMD  30 mois après le diplôme            hommes
# 1970   MASTER LMD  30 mois après le diplôme            femmes
# ...           ...                       ...               ...
# 1970   MASTER LMD  30 mois après le diplôme            hommes
# 1970   MASTER LMD  18 mois après le diplôme            hommes
# 1970   MASTER LMD  30 mois après le diplôme            hommes
# 1970   MASTER LMD  30 mois après le diplôme  femmes et hommes
# 1970   MASTER LMD  30 mois après le diplôme  femmes et hommes
#
#                                              Disciplines Code du domaine  \
# Année
# 1970   Masters enseignement>Masters enseignement>Mast...            MEEF
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# 1970   Sciences, technologies et santé>Sciences fonda...             STS
# ...                                                  ...             ...
# 1970   Sciences humaines et sociales>Autres sciences ...             SHS
# 1970   Sciences humaines et sociales>Autres sciences ...             SHS
# 1970   Sciences humaines et sociales>Autres sciences ...             SHS
# 1970   Sciences humaines et sociales>Autres sciences ...             SHS
# 1970   Sciences humaines et sociales>Autres sciences ...             SHS
#
#                                Domaine Code de la discipline  \
# Année
# 1970              Masters enseignement                disc18
# 1970   Sciences, technologies et santé                disc14
# 1970   Sciences, technologies et santé                disc14
# 1970   Sciences, technologies et santé                disc14
# 1970   Sciences, technologies et santé                disc14
# ...                                ...                   ...
# 1970     Sciences humaines et sociales                disc11
# 1970     Sciences humaines et sociales                disc11
# 1970     Sciences humaines et sociales                disc11
# 1970     Sciences humaines et sociales                disc11
# 1970     Sciences humaines et sociales                disc11
#
#                                  Discipline Sigle Spécialité  ...  \
# Année                                                         ...
# 1970                   Masters enseignement   NaN        NaN  ...
# 1970                 Sciences fondamentales   NaN        NaN  ...
# 1970                 Sciences fondamentales   NaN        NaN  ...
# 1970                 Sciences fondamentales   NaN        NaN  ...
# 1970                 Sciences fondamentales   NaN        NaN  ...
# ...                                     ...   ...        ...  ...
# 1970   Autres sciences humaines et sociales   NaN        NaN  ...
# 1970   Autres sciences humaines et sociales   NaN        NaN  ...
# 1970   Autres sciences humaines et sociales   NaN        NaN  ...
# 1970   Autres sciences humaines et sociales   NaN        NaN  ...
# 1970   Autres sciences humaines et sociales   NaN        NaN  ...
#
#          Secteur disciplinaire Administration publique (hors ens.)  \
# Année
# 1970      Masters enseignement                                 NaN
# 1970        Physique et chimie                                 NaN
# 1970        Physique et chimie                                 NaN
# 1970        Physique et chimie                                 NaN
# 1970                  Physique                                 NaN
# ...                        ...                                 ...
# 1970   Sciences de l'éducation                                 NaN
# 1970   Sciences de l'éducation                                 NaN
# 1970   Sciences de l'éducation                                 NaN
# 1970   Sciences de l'éducation                                 NaN
# 1970   Sciences de l'éducation                                 NaN
#
#       Prof. libérale, indépendant, chef d’entreprise  \
# Année
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# ...                                              ...
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
# 1970                                             NaN
#
#       Contrat de professionnalisation  \
# Année
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# ...                               ...
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
# 1970                              NaN
#
#       La fonction publique (d'etat, territoriale ou hospitalière)  \
# Année
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# ...                                                  ...
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
#
#       Organisation internationale ou une institution de l'Union européenne  \
# Année
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# ...                                                  ...
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
#
#       Société d'économie mixte Agriculture, sylviculture et pêche  \
# Année
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# ...                        ...                                ...
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
# 1970                       NaN                                NaN
#
#       Artisan, commerçant, chef d'entreprise  \
# Année
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# ...                                      ...
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
# 1970                                     NaN
#
#       Ingénieur, cadre, prof. libérales, prof. intellectuelles sup
# Année
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# ...                                                  ...
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
# 1970                                                 NaN
#
# [2925 rows x 85 columns]
